# %% [markdown]
# # Streaming
#
# <img src="./assets/LC_streaming.png" width="400">
#
# Streaming reduces the latency between generating data and the user receiving it.
# There are two types frequently used with Agents:

# %% [markdown]
# ## Setup

# %% [markdown]
# Load and/or check for needed environmental variables

# %%
from dotenv import load_dotenv

from env_utils import doublecheck_env

# Load environment variables from .env
load_dotenv()

# Check and print results
doublecheck_env("example.env")
# Out:
# OPENAI_API_KEY=****_1cA
# LANGSMITH_API_KEY=****7ac4
# LANGSMITH_TRACING=true
# LANGSMITH_PROJECT=****ials

# %%
from langchain.agents import create_agent

# %%
agent = create_agent(
    model="openai:gpt-5",
    system_prompt="You are a full-stack comedian",
)

# %% [markdown]
# ## No Streaming (invoke)

# %%
result = agent.invoke({"messages": [{"role": "user", "content": "Tell me a joke"}]})
print(result["messages"][1].content)
# Out:
# I tried to tell a JavaScript joke, but the punchline was asynchronous—everyone laughed three seconds later.

# %% [markdown]
# ## `values`
# You have seen this streaming mode in our examples so far.

# %%
# Stream = values
for step in agent.stream(
    {"messages": [{"role": "user", "content": "Tell me a Dad joke"}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Tell me a Dad joke
# ================================== Ai Message ==================================
#
# What do you call fake spaghetti? An impasta.

# %% [markdown]
# ## `messages`
# Messages stream data token by token - the lowest latency possible. This is perfect for interactive applications like chatbots.

# %%
for token, metadata in agent.stream(
    {"messages": [{"role": "user", "content": "Write me a family friendly poem."}]},
    stream_mode="messages",
):
    print(f"{token.content}", end="")
# Out:
# The House That Laughs
#
# Our house wakes up like toast that pops,
# Sunlight does cartwheels over mops.
# The cat holds meetings on the stair—
# Agenda item one: “My chair.”
#
# Dad stirs pancakes, flips a pun,
# Calls them “flour power,” one by one.
# Mom’s eight calendars juggle air;
# She high-fives Tuesday, braids its hair.
#
# My brother bargains with his peas:
# “Two bites and I’ll sign the treaty, please.”
# My sister builds a blanket state,
# With teddy guards at every gate.
#
# Grandpa’s remote, an ancient rune,
# Finds documentaries by noon.
# The dog, a furry vacuum zoom,
# Collects the crumbs, patrols the room.
#
# A sock escapes the laundry sea,
# Returns as puppet royalty.
# Wi‑Fi hiccups—no big deal—
# We dust off cards; the laughs are real.
#
# At bedtime, stars tap on the glass;
# We chart a route to Dreamland’s pass.
# “Love you to the fridge and back,”
# Then night tucks in our cozy stack.

# %% [markdown]
# ## Tools can stream too!
# Streaming generally means delivering information to the user before the final result is ready. There are many cases where this is useful. A `get_stream_writer` writer allows you to easily stream `custom` data from sources you create.

# %%
from langchain.agents import create_agent
from langchain_core.tools import tool
from langgraph.config import get_stream_writer


@tool
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    writer = get_stream_writer()
    # stream any arbitrary data
    writer(f"Looking up data for city: {city}")
    writer(f"Acquired data for city: {city}")
    return f"It's always sunny in {city}!"


agent = create_agent(
    model="openai:gpt-5-mini",
    tools=[get_weather],
)

for chunk in agent.stream(
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode=["values", "custom"],
):
    print(chunk)
# Out:
# ('values', {'messages': [HumanMessage(content='What is the weather in SF?', additional_kwargs={}, response_metadata={}, id='2c3e7c2f-65d3-4c20-8eeb-bdf3ebe6295e')]})
# ('values', {'messages': [HumanMessage(content='What is the weather in SF?', additional_kwargs={}, response_metadata={}, id='2c3e7c2f-65d3-4c20-8eeb-bdf3ebe6295e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 132, 'total_tokens': 220, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DBdVHCSmTFafO0gpe5L9XsO9rk0FQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7f83-32f0-78a1-b4b2-0f4015752f90-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'San Francisco'}, 'id': 'call_DPMxcyhQ3LZixpFWlUVwUvES', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 132, 'output_tokens': 88, 'total_tokens': 220, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})]})
# ('custom', 'Looking up data for city: San Francisco')
# ('custom', 'Acquired data for city: San Francisco')
# ('values', {'messages': [HumanMessage(content='What is the weather in SF?', additional_kwargs={}, response_metadata={}, id='2c3e7c2f-65d3-4c20-8eeb-bdf3ebe6295e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 132, 'total_tokens': 220, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DBdVHCSmTFafO0gpe5L9XsO9rk0FQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7f83-32f0-78a1-b4b2-0f4015752f90-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'San Francisco'}, 'id': 'call_DPMxcyhQ3LZixpFWlUVwUvES', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 132, 'output_tokens': 88, 'total_tokens': 220, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), ToolMessage(content="It's always sunny in San Francisco!", name='get_weather', id='ff0cd759-92f9-45c4-947d-6e40e9495ce7', tool_call_id='call_DPMxcyhQ3LZixpFWlUVwUvES')]})
# ('values', {'messages': [HumanMessage(content='What is the weather in SF?', additional_kwargs={}, response_metadata={}, id='2c3e7c2f-65d3-4c20-8eeb-bdf3ebe6295e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 132, 'total_tokens': 220, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DBdVHCSmTFafO0gpe5L9XsO9rk0FQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7f83-32f0-78a1-b4b2-0f4015752f90-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'San Francisco'}, 'id': 'call_DPMxcyhQ3LZixpFWlUVwUvES', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 132, 'output_tokens': 88, 'total_tokens': 220, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), ToolMessage(content="It's always sunny in San Francisco!", name='get_weather', id='ff0cd759-92f9-45c4-947d-6e40e9495ce7', tool_call_id='call_DPMxcyhQ3LZixpFWlUVwUvES'), AIMessage(content='I checked San Francisco — the report says: “It’s always sunny in San Francisco!” \n\nWould you like more specific details (current temperature, hourly forecast, rain/wind alerts) or weather for a different city?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 181, 'prompt_tokens': 168, 'total_tokens': 349, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DBdVJZblb7vFc3zeDHztt90JCYhJr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7f83-3d61-7dc3-b7b6-757f29e8cb5c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 168, 'output_tokens': 181, 'total_tokens': 349, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]})

# %%
from langchain_core.messages import AIMessageChunk

answer = []

for chunk in agent.stream(
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode=["messages", "custom"],
):
    chunk_type, content = chunk
    
    print("=====================================================================")
    print(f"chunk type: {chunk_type}")
    
    if chunk_type == "messages":
        print(f"message: {content[0]}")
        print(f"metadata: {content[1]}")
        
        if (isinstance(content[0], AIMessageChunk) and not content[0].tool_calls and 
            not content[0].tool_call_chunks and not content[0].additional_kwargs):
            answer.append(content[0].content)
    else:
        print(f"message: {chunk[-1]}")
# Out:
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[{'name': 'get_weather', 'args': {}, 'id': 'call_l3xIu06rRaoNbUsnAsmT0R9U', 'type': 'tool_call'}] invalid_tool_calls=[] tool_call_chunks=[{'name': 'get_weather', 'args': '', 'id': 'call_l3xIu06rRaoNbUsnAsmT0R9U', 'index': 0, 'type': 'tool_call_chunk'}]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[{'name': '', 'args': {}, 'id': None, 'type': 'tool_call'}] invalid_tool_calls=[] tool_call_chunks=[{'name': None, 'args': '{"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': 'city', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'city', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': '":"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '":"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': 'San', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'San', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': ' Francisco', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': ' Francisco', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': '"}', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '"}', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-5-mini-2025-08-07', 'service_tier': 'default', 'model_provider': 'openai'} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 132, 'output_tokens': 152, 'total_tokens': 284, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}} tool_call_chunks=[]
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={} id='lc_run--019c7f83-4b42-7931-a601-367951756b40' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[] chunk_position='last'
# metadata: {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'checkpoint_ns': 'model:0955ca57-83f5-516d-4f6a-e055baeafc51', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'LANGSMITH_PROJECT': 'lca-lc-essentials', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'a2c2c30-dirty'}
# =====================================================================
# chunk type: custom
# message: Looking up data for city: San Francisco
# =====================================================================
# chunk type: custom
# message: Acquired data for city: San Francisco
# =====================================================================
# chunk type: messages
# message: content="It's always sunny in San Francisco!" name='get_weather' id='c20beaae-b4c8-44c4-ad44-5b8f871ab626' tool_call_id='call_l3xIu06rRaoNbUsnAsmT0R9U'
# metadata: {'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'tools:1ddedaf1-49a5-85e5-62ea-25a28b16fcd6', 'LANGSMITH_PROJECT': 'lca-lc-essentials', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'a2c2c30-dirty'}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='According' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' to' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' the' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' weather' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' service' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=':' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' "' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content="It's" additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' always' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' sunny' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' in' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' San' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' Francisco' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='!"' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' \n\n' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='Want' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' a' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' real' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='-time' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' temperature' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=',' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' hourly' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' forecast' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=',' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' or' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' a' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' ' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='7' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='-day' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content=' outlook' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='?' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-5-mini-2025-08-07', 'service_tier': 'default', 'model_provider': 'openai'} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 168, 'output_tokens': 168, 'total_tokens': 336, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}} tool_call_chunks=[]
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None}
# =====================================================================
# chunk type: messages
# message: content='' additional_kwargs={} response_metadata={} id='lc_run--019c7f83-554b-7ac3-9828-af37190f97d9' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[] chunk_position='last'
# metadata: {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'checkpoint_ns': 'model:37c3c71b-a547-acd0-77f3-894716f4b3c0', 'ls_provider': 'openai', 'ls_model_name': 'gpt-5-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'LANGSMITH_PROJECT': 'lca-lc-essentials', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'a2c2c30-dirty'}

# %%
print("")
print("".join(answer))
# Out:
# According to the weather service: "It's always sunny in San Francisco!"
#
# Want a real-time temperature, hourly forecast, or a 7-day outlook?

# %%
for token, metadata in agent.stream(
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode="messages",
):
    print(f"{token.content}", end="")
# Out:
# It's always sunny in San Francisco!"It's always sunny in San Francisco!"
#
# Would you like the current temperature, hourly forecast, or weather for a different city?

# %% [markdown]
# The things will be different if we just only use `message`, there will be `token` and `metadata` to stream. It make to be focus on messages only.

# %%
for token, metadata in agent.stream(
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode="messages",
):
    print(token)
# Out:
# content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[{'name': 'get_weather', 'args': {}, 'id': 'call_rST5a0GaSsa1ABpebH16E9Dk', 'type': 'tool_call'}] invalid_tool_calls=[] tool_call_chunks=[{'name': 'get_weather', 'args': '', 'id': 'call_rST5a0GaSsa1ABpebH16E9Dk', 'index': 0, 'type': 'tool_call_chunk'}]
# content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[{'name': '', 'args': {}, 'id': None, 'type': 'tool_call'}] invalid_tool_calls=[] tool_call_chunks=[{'name': None, 'args': '{"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': 'city', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'city', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': '":"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '":"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': 'San', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': 'San', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': ' Francisco', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': ' Francisco', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[] invalid_tool_calls=[{'name': None, 'args': '"}', 'id': None, 'error': None, 'type': 'invalid_tool_call'}] tool_call_chunks=[{'name': None, 'args': '"}', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}]
# content='' additional_kwargs={} response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-5-mini-2025-08-07', 'service_tier': 'default', 'model_provider': 'openai'} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='' additional_kwargs={} response_metadata={} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 132, 'output_tokens': 24, 'total_tokens': 156, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}} tool_call_chunks=[]
# content='' additional_kwargs={} response_metadata={} id='lc_run--019c7f83-7260-7713-8f87-93bd1fd8998d' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[] chunk_position='last'
# content="It's always sunny in San Francisco!" name='get_weather' id='1e53e89d-04f9-4d0f-8c53-ae9c20eee57b' tool_call_id='call_rST5a0GaSsa1ABpebH16E9Dk'
# content='' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='According' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' to' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' my' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' source' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=':' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' "' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content="It's" additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' always' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' sunny' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' in' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' San' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' Francisco' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='!"\n\n' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='Would' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' you' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' like' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' more' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' details' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' (' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='current' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' temperature' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=',' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' hourly' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' forecast' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=',' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' or' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' a' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' ' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='7' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='-day' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' outlook' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=')?' additional_kwargs={} response_metadata={'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-5-mini-2025-08-07', 'service_tier': 'default', 'model_provider': 'openai'} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='' additional_kwargs={} response_metadata={} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 168, 'output_tokens': 169, 'total_tokens': 337, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}} tool_call_chunks=[]
# content='' additional_kwargs={} response_metadata={} id='lc_run--019c7f83-7967-71b3-b4c2-277a14577e29' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[] chunk_position='last'

# %% [markdown]
# ## Try different modes on your own!
# Modify the stream mode and the select to produce different results.

# %%
for chunk in agent.stream(
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode=["values", "custom"],
):
    if chunk[0] == "custom":
        print(chunk[1])
# Out:
# Looking up data for city: San Francisco
# Acquired data for city: San Francisco
